# %%
import h5py
import glob
import torch
import numpy as np

import sys
sys.path.append("../../")

# %%
files = glob.glob("../../final_data/cifar/*.hdf5")

for file in files:
    print(file.split("/")[-1])
    with h5py.File(file, "r") as f:
        for k in f.keys():
            print(k, f[k].shape)
# Out:
# dataset_train_orig.hdf5
# C (1200, 20, 3, 32, 32)
# Q (2400, 6, 3, 32, 32)
# labels (2400, 10)
# dataset_val_orig.hdf5
# C (600, 20, 3, 32, 32)
# Q (1200, 6, 3, 32, 32)
# labels (1200, 10)
# dataset_val.hdf5
# C (600, 20, 384)
# Q (1200, 6, 384)
# labels (1200, 10)
# dataset_train.hdf5
# C (1200, 20, 384)
# Q (2400, 6, 384)
# labels (2400, 10)
# dataset_test_orig.hdf5
# C (600, 20, 3, 32, 32)
# Q (1200, 6, 3, 32, 32)
# labels (1200, 10)
# dataset_test.hdf5
# C (600, 20, 384)
# Q (1200, 6, 384)
# labels (1200, 10)
